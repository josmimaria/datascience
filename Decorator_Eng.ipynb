# %% [markdown]
# <a href="https://colab.research.google.com/github/josmimaria/datascience/blob/development/Decorator_Eng.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def test():
    print("this is the start of my fun")
    print(4+5)
    print("this is the end of my fun")

# %%
test()
# Out:
# this is the start of my fun
# 9
# this is the end of my fun

# %%
def deco(func):
    def inner_deco():
        print("this is the start of my fun")
        func()
        print("this is the end of my fun")
    return inner_deco

# %%
@deco
def test1():
    print(4+5)

# %%
test1()
# Out:
# this is the start of my fun
# 9
# this is the end of my fun

# %%
import time
def timer_test(func) :
    def timer_test_inner():
        start = time.time()
        func()
        end = time.time()
        print(end-start)
    return timer_test_inner

# %%
@timer_test
def test2():
    print(45+67)

# %%
test2()
# Out:
# 112
# 0.0007147789001464844

# %%
@timer_test
def test3():
    for i in range(100000000):
        pass

# %%
test3()
# Out:
# 5.382972717285156
