# %% [markdown]
# <a href="https://colab.research.google.com/github/josmimaria/datascience/blob/development/List_Of_General_Use_Exceptions_Eng.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try :
    a = 10
    10/0
except ZeroDivisionError as e :
    print(e)
# Out:
# division by zero

# %%
try :
    int("sudh")
except (ValueError , TypeError) as e :
    print(e)
# Out:
# invalid literal for int() with base 10: 'sudh'

# %%
try :
    int("sudh")
except  :
    print("this will catch an error")
# Out:
# this will catch an error

# %%
try :
    import sudh
except ImportError as e :
    print(e)
# Out:
# No module named 'sudh'

# %%
try :
    d = {1: [3,4,5,6] , "key" :"sudh"}
    d["key10"]
except KeyError as e :
    print(e)
# Out:
# 'key10'

# %%
try :
    "sudh".test()
except AttributeError as e :
    print(e)
# Out:
# 'str' object has no attribute 'test'

# %%
try :
    l = [1,2,3,3]
    l[10]
except IndexError as e :
    print(e)
# Out:
# list index out of range

# %%
try :
    123 + "sudh"
except TypeError as e :
    print(e)
# Out:
# unsupported operand type(s) for +: 'int' and 'str'

# %%
try :
    with open("test.txt" , 'r') as f :
        f.read()
except FileNotFoundError as e :
    print(e)
# Out:
# [Errno 2] No such file or directory: 'test.txt'

# %%
try :
    with open("test.txt" , 'r') as f :
        f.read()
except Exception as e :
    print("test " , e)
except FileNotFoundError as e :
    print("this is my file not found type error " , e)
# Out:
# test  [Errno 2] No such file or directory: 'test.txt'

# %%
def test(file):
    try :
        with open(file, 'r') as f :
            f.read()
    except Exception as e :
        print("test " , e)
    except FileNotFoundError as e :
        print("this is my file not found type error " , e)
