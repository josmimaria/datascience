# %% [markdown]
# <a href="https://colab.research.google.com/github/josmimaria/datascience/blob/development/Logging_%26_Debugger_eng.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("this is my print stamt")
# Out:
# this is my print stamt

# %%
import logging

# %%
logging.basicConfig(filename = "test.log" , level = logging.INFO, force=True )

# %%
logging.info("this is my line of execution ")

# %%
logging.error("this is my error")

# %%
logging.critical("this is my critical")

# %%
logging.warning("this is my warning ")

# %%
logging.debug("this is my info related to debug")

# %%
logging.noset("this is my noset related log")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_530/4020266339.py in <cell line: 0>()
# ----> 1 logging.noset("this is my noset related log")
#
# AttributeError: module 'logging' has no attribute 'noset'

# %%
logging.shutdown()

# %%
1. NOSET
2. DEBUG
3. INFO
4. WARNING
5. ERROR
6. CRITICAL
# Out:
#   File "/tmp/ipykernel_530/3027634766.py", line 1
#     1. NOSET
#        ^
# SyntaxError: invalid syntax

# %%
logging.basicConfig(filename = "test1.log" , level = logging.DEBUG ,format = '%(asctime)s %(message)s' , force=True )

# %%
logging.info("this is my info log")

# %%
logging.debug("this is my debug log")

# %%
logging.warning("this is my warning ")

# %%
logging.shutdown()

# %%
logging.basicConfig(filename = "test3.log" , level = logging.DEBUG, format = '%(asctime)s %(name)s %(levelname)s  %(message)s', force=True)

# %%
logging.info("this is my info log")

# %%
l = [1,2,3,4,[4,5,6] , "sudh" ,"kumar"]

# %%
l1_int = []
l2_str = []
for i in l :
    logging.info("this is the start of my first for loop {}".format(l))
    logging.info("this is the value of i am logging {}".format(i))
    if type(i) == list:
        for j in i :
            logging.info("logggin my j {j} and i is {i}".format(i = i ,j = j))
            if type(j) == int :
                l1_int.append(j)
    elif type(i) == int :
        l1_int.append(i)

    else :
        if type(i) == str:
            l2_str.append(i)
logging.info("this is my final result  with all int {l1} ,with all str{l2}".format(l1 =l1_int ,l2 =l2_str ))

# %%
l1_int
# Out:
# [1, 2, 3, 4, 4, 5, 6]

# %%
l2_str
# Out:
# ['sudh', 'kumar']
