# %% [markdown]
# <a href="https://colab.research.google.com/github/josmimaria/datascience/blob/development/Polymorphism_eng.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def test(a,b) :
    return a+b

# %%
test(4,5)
# Out:
# 9

# %%
test("sudh " , "kumar")
# Out:
# 'sudh kumar'

# %%
test([2,3,4,5,5] , [4,5,6,7])
# Out:
# [2, 3, 4, 5, 5, 4, 5, 6, 7]

# %%
class data_science:
    def syllabus(self) :
        print("this is my method for data science syllbaus " )

# %%
class web_dev :
    def syllabus(self) :
        print("this is my method for web dev " )

# %%
def class_parcer(class_obj) :
    for i in class_obj :
        i.syllabus()

# %%
obj_data_science= data_science()

# %%
obj_web_dev = web_dev()

# %%
class_ojb = [obj_data_science , obj_web_dev]

# %%
class_parcer(class_ojb)
# Out:
# this is my method for data science syllbaus
# this is my method for web dev
