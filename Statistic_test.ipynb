# %% [markdown]
# <a href="https://colab.research.google.com/github/josmimaria/datascience/blob/test/Statistic_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
import statistics

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#mean, median, mode
#df = pd.read_csv("/content/drive/MyDrive/Thesis/AndMal17.csv")

df = pd.read_csv("/content/drive/MyDrive/statistics/student_performance.csv")
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   student_id            500 non-null    object
#  1   gender                500 non-null    object
#  2   age                   500 non-null    int64
#  3   study_hours_per_week  500 non-null    int64
#  4   attendance_rate       500 non-null    float64
#  5   parent_education      383 non-null    object
#  6   internet_access       500 non-null    object
#  7   extracurricular       500 non-null    object
#  8   previous_score        500 non-null    int64
#  9   final_score           500 non-null    int64
#  10  passed                500 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 43.1+ KB
#               age  study_hours_per_week  attendance_rate  previous_score  \
# ...

# %%
print(df.isnull().sum())

# %% [markdown]
# **Data Cleaning**

# %%
# Drop ID column
df = df.drop("student_id", axis=1)

# Check missing values
print(df.isnull().sum())
# Out:
# gender                    0
# age                       0
# study_hours_per_week      0
# attendance_rate           0
# parent_education        117
# internet_access           0
# extracurricular           0
# previous_score            0
# final_score               0
# passed                    0
# dtype: int64

# %%
np.mean(df['final_score'])
# Out:
# np.float64(55.98)

# %%
newdf = df[(df["final_score"] >= 48) & (df["final_score"] <= 55)]
count = newdf.count()
print(count)
# Out:
# student_id              88
# gender                  88
# age                     88
# study_hours_per_week    88
# attendance_rate         88
# parent_education        70
# internet_access         88
# extracurricular         88
# previous_score          88
# final_score             88
# passed                  88
# dtype: int64

# %% [markdown]
# **Exploratory Data Analysis (EDA)**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['final_score'])
plt.show()

sns.boxplot(x='gender', y='final_score', data=df)
plt.show()
