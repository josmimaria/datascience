# %% [markdown]
# <a href="https://colab.research.google.com/github/josmimaria/datascience/blob/development/String.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
t1 = (1,2,3,4)

# %%
t1
# Out:
# (1, 2, 3, 4)

# %%
type(t1)
# Out:
# tuple

# %%
t1[2]
# Out:
# 3

# %%
t1[::-1]
# Out:
# (4, 3, 2, 1)

# %%
t1
# Out:
# (1, 2, 3, 4)

# %%
t1 = t1[::-1]

# %%
t1
# Out:
# (4, 3, 2, 1)

# %%
t1[0:3]
# Out:
# (4, 3, 2)

# %%
t2=[1,2,9,4]

# %%
t2
# Out:
# [1, 2, 9, 4]

# %%
type(t2)
# Out:
# list

# %%
t2[2]
# Out:
# 9

# %%
t2[::-1]
# Out:
# [4, 9, 2, 1]

# %%
t2[0]=100

# %%
t2
# Out:
# [100, 2, 9, 4]

# %%
t3=(t1,t2)

# %%
t3
# Out:
# ((4, 3, 2, 1), [100, 2, 9, 4])

# %%
len(t1)
# Out:
# 4

# %%
t2.count(2)
# Out:
# 1

# %%
t1.count(2)
# Out:
# 1

# %%
len(t2)
# Out:
# 4

# %%
len(t3)
# Out:
# 2

# %%
"jos" in t2
# Out:
# False

# %%
2 in t2
# Out:
# True

# %%
9 in t3
# Out:
# False

# %%
t1 in t3
# Out:
# True

# %%
del t3

# %%
t3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2847/2633524244.py in <cell line: 0>()
# ----> 1 t3
#
# NameError: name 't3' is not defined

# %%
d1={}

# %%
type(d1)
# Out:
# dict

# %%
d1={"name":"Josmi", "Age": 33, "Education":"Masters in datascience"}

# %%
d1
# Out:
# {'name': 'Josmi', 'Age': 33, 'Education': 'Masters in datascience'}

# %%
type(d1)
# Out:
# dict

# %%
d2={1:"one"}

# %%
d3={12.23: "tessr"}

# %%
d4={(1,2,4):"23232"}

# %%
d5={[1,2,3]:"wew"}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2847/2879229349.py in <cell line: 0>()
# ----> 1 d5={[1,2,3]:"wew"}
#
# TypeError: unhashable type: 'list'

# %%
d6={True:"true"}

# %%
d7={#:"sds"}
# Out:
#   File "/tmp/ipykernel_2847/2798817764.py", line 1
#     d7={#:"sds"}
#                 ^
# SyntaxError: incomplete input

# %%
d8={&:"ds"}
# Out:
#   File "/tmp/ipykernel_2847/2513614010.py", line 1
#     d8={&:"ds"}
#         ^
# SyntaxError: invalid syntax

# %%
d11={"test":[1,2,3,4]}

# %%
d12={"test1":{"key1":"value1","key2":"value2","key3":"value3"}}

# %%
d12["batch"]=["dsa","bca","ML","AI","deep learning"]

# %%
d12
# Out:
# {'test1': {'key1': 'value1', 'key2': 'value2', 'key3': 'value3'},
#  'batch': ['dsa', 'bca', 'ML', 'AI', 'deep learning']}

# %%
list(d12["batch"])
# Out:
# ['dsa', 'bca', 'ML', 'AI', 'deep learning']

# %%
d12["name"]="Paulo"

# %%
d12
# Out:
# {'test1': {'key1': 'value1', 'key2': 'value2', 'key3': 'value3'},
#  'batch': ['dsa', 'bca', 'ML', 'AI', 'deep learning'],
#  'name': 'Paulo'}

# %%
d12['name'].upper()
# Out:
# 'PAULO'

# %%
d12.keys()
# Out:
# dict_keys(['test1', 'batch', 'name'])

# %%
list(d12.keys())
# Out:
# ['test1', 'batch', 'name']

# %%
list(d12.values())
# Out:
# [{'key1': 'value1', 'key2': 'value2', 'key3': 'value3'},
#  ['dsa', 'bca', 'ML', 'AI', 'deep learning'],
#  'Paulo']

# %%
del d12['name']

# %%
d12
# Out:
# {'test1': {'key1': 'value1', 'key2': 'value2', 'key3': 'value3'},
#  'batch': ['dsa', 'bca', 'ML', 'AI', 'deep learning']}

# %%
d12["email"]="jk@gmail.com"

# %%
d12
# Out:
# {'test1': {'key1': 'value1', 'key2': 'value2', 'key3': 'value3'},
#  'batch': ['dsa', 'bca', 'ML', 'AI', 'deep learning'],
#  'email': 'jk@gmail.com'}

# %%
d12.pop('email')
# Out:
# 'jk@gmail.com'

# %%
d12
# Out:
# {'test1': {'key1': 'value1', 'key2': 'value2', 'key3': 'value3'},
#  'batch': ['dsa', 'bca', 'ML', 'AI', 'deep learning']}

# %%
d1
# Out:
# {'name': 'Josmi', 'Age': 33, 'Education': 'Masters in datascience'}

# %%
d1.clear()

# %%
d1
# Out:
# {}

# %%
d12
# Out:
# {'test1': {'key1': 'value1', 'key2': 'value2', 'key3': 'value3'},
#  'batch': ['dsa', 'bca', 'ML', 'AI', 'deep learning']}

# %%
d12.items()
# Out:
# dict_items([('test1', {'key1': 'value1', 'key2': 'value2', 'key3': 'value3'}), ('batch', ['dsa', 'bca', 'ML', 'AI', 'deep learning'])])

# %%
list(d12.items())
# Out:
# [('test1', {'key1': 'value1', 'key2': 'value2', 'key3': 'value3'}),
#  ('batch', ['dsa', 'bca', 'ML', 'AI', 'deep learning'])]

# %%
d2
# Out:
# {1: 'one'}

# %%
d12
# Out:
# {'test1': {'key1': 'value1', 'key2': 'value2', 'key3': 'value3'},
#  'batch': ['dsa', 'bca', 'ML', 'AI', 'deep learning']}

# %%
d12["name"]="josmi"

# %%
d12
# Out:
# {'test1': {'key1': 'value1', 'key2': 'value2', 'key3': 'value3'},
#  'batch': ['dsa', 'bca', 'ML', 'AI', 'deep learning'],
#  'name': 'josmi'}

# %%
d15=d12.copy()

# %%
d15
# Out:
# {'test1': {'key1': 'value1', 'key2': 'value2', 'key3': 'value3'},
#  'batch': ['dsa', 'bca', 'ML', 'AI', 'deep learning'],
#  'name': 'josmi'}

# %%
d16=d12

# %%
d16
# Out:
# {'test1': {'key1': 'value1', 'key2': 'value2', 'key3': 'value3'},
#  'batch': ['dsa', 'bca', 'ML', 'AI', 'deep learning'],
#  'name': 'josmi'}

# %%
d12.pop('name')
# Out:
# 'josmi'

# %%
d12
# Out:
# {'test1': {'key1': 'value1', 'key2': 'value2', 'key3': 'value3'},
#  'batch': ['dsa', 'bca', 'ML', 'AI', 'deep learning']}

# %%
d15
# Out:
# {'test1': {'key1': 'value1', 'key2': 'value2', 'key3': 'value3'},
#  'batch': ['dsa', 'bca', 'ML', 'AI', 'deep learning'],
#  'name': 'josmi'}

# %%
d16
# Out:
# {'test1': {'key1': 'value1', 'key2': 'value2', 'key3': 'value3'},
#  'batch': ['dsa', 'bca', 'ML', 'AI', 'deep learning']}

# %%
d1.fromkeys((1,2,3),('a','b','c'))
# Out:
# {1: ('a', 'b', 'c'), 2: ('a', 'b', 'c'), 3: ('a', 'b', 'c')}

# %%
d17={"key1":"value1","key2":"value2"}
d18={"key3":"value3","key4":"value4"}

# %%
(d17,d18)
# Out:
# ({'key1': 'value1', 'key2': 'value2'}, {'key3': 'value3', 'key4': 'value4'})

# %%
d17.update(d18)

# %%
d17
# Out:
# {'key1': 'value1', 'key2': 'value2', 'key3': 'value3', 'key4': 'value4'}

# %%
d18
# Out:
# {'key3': 'value3', 'key4': 'value4'}

# %%
d17.get("key2")
# Out:
# 'value2'

# %%
d17.get("astro")

# %%
d17["astro"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_2847/3590301247.py in <cell line: 0>()
# ----> 1 d17["astro"]
#
# KeyError: 'astro'

# %%
{i: i**2 for i in range(1,11)}
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}

# %%
{i:i+10 for i in range(1,11)}
# Out:
# {1: 11, 2: 12, 3: 13, 4: 14, 5: 15, 6: 16, 7: 17, 8: 18, 9: 19, 10: 20}

# %%
import math
{i:math.log10(i) for i in range(1,11)}
# Out:
# {1: 0.0,
#  2: 0.3010299956639812,
#  3: 0.47712125471966244,
#  4: 0.6020599913279624,
#  5: 0.6989700043360189,
#  6: 0.7781512503836436,
#  7: 0.8450980400142568,
#  8: 0.9030899869919435,
#  9: 0.9542425094393249,
#  10: 1.0}

# %%
import math
d31= {i:math.log10(i) for i in range(1,11)}

# %%
d31
# Out:
# {1: 0.0,
#  2: 0.3010299956639812,
#  3: 0.47712125471966244,
#  4: 0.6020599913279624,
#  5: 0.6989700043360189,
#  6: 0.7781512503836436,
#  7: 0.8450980400142568,
#  8: 0.9030899869919435,
#  9: 0.9542425094393249,
#  10: 1.0}

# %%
for i in d31.keys():
  if i%2==0:
    print(d31[i])
# Out:
# 0.3010299956639812
# 0.6020599913279624
# 0.7781512503836436
# 0.9030899869919435
# 1.0

# %%
[d31[i] for i in d31.keys() if i%2==0]
# Out:
# [0.3010299956639812,
#  0.6020599913279624,
#  0.7781512503836436,
#  0.9030899869919435,
#  1.0]

# %%
var = 10
bin(var)
# Out:
# '0b1010'

# %%
~var
# Out:
# -11

# %%
True | False
# Out:
# True

# %%
var >> 1
# Out:
# 5

# %%
var << 1
# Out:
# 20

# %%
var << 2
# Out:
# 40

# %%
bin(var << 2)
# Out:
# '0b101000'

# %%
str1 = " Data Science"

# %%
str1[:]
# Out:
# ' Data Science'

# %%
str1[::]
# Out:
# ' Data Science'

# %%
str1[::-1]
# Out:
# 'ecneicS ataD '

# %%
course_anme= "Data Science Masters"

# %%
course_anme[::-1]
# Out:
# 'sretsaM ecneicS ataD'

# %%
course_anme[::1]
# Out:
# 'Data Science Masters'

# %%
course_anme[5:12]
# Out:
# 'Science'

# %%
course_anme[11:4:-1]
# Out:
# 'ecneicS'

# %%
course_anme + " Course"
# Out:
# 'Data Science Masters Course'

# %%
str2 = "Josmi"

# %%
str2 * 5
# Out:
# 'JosmiJosmiJosmiJosmiJosmi'

# %%
len(str2)
# Out:
# 5

# %%
str2.find("s")
# Out:
# 2

# %%
str2.find("z")
# Out:
# -1

# %%
course_anme
# Out:
# 'Data Science Masters'

# %%
course_anme.find("a")  # return only very first index of "a"
# Out:
# 1

# %%
course_anme.find("a",2,6) # find a in between the 2nd and 6th index, it return only first index of "a" in between 2 qnd 6 index
# Out:
# 3

# %%
course_anme.count("a")
# Out:
# 3

# %%
course_anme.count(" ")
# Out:
# 2

# %%
from posixpath import split
course_anme.split(' ')
# Out:
# ['Data', 'Science', 'Masters']

# %%
course_anme
# Out:
# 'Data Science Masters'

# %%
course_anme.count('')
# Out:
# 21

# %%
from posixpath import split
course_anme.split("S")
# Out:
# ['Data ', 'cience Masters']

# %%
course_anme.partition("S")
# Out:
# ('Data ', 'S', 'cience Masters')

# %%
course_anme.upper()
# Out:
# 'DATA SCIENCE MASTERS'

# %%
course_anme.lower()
# Out:
# 'data science masters'

# %%
course_anme.swapcase()
# Out:
# 'dATA sCIENCE mASTERS'

# %%
course_anme.title()
# Out:
# 'Data Science Masters'

# %%
course_anme
# Out:
# 'Data Science Masters'

# %%
course_anme.swapcase()
# Out:
# 'dATA sCIENCE mASTERS'

# %%
course_anme.capitalize()
# Out:
# 'Data science masters'

# %% [markdown]
# **Reversing a String**

# %%
course_anme[::-1]
# Out:
# 'sretsaM ecneicS ataD'

# %%
reversed(course_anme)

# %%
' '.join(reversed(course_anme))
# Out:
# 's r e t s a M   e c n e i c S   a t a D'

# %%
"Data".join("Science")
# Out:
# 'SDatacDataiDataeDatanDatacDatae'

# %%
from os.path import join
' '.join("ant")
# Out:
# 'a n t'

# %%
from os.path import join
' '.join(reversed("ant"))
# Out:
# 't n a'

# %%
from posixpath import join
' DataScience '.join(reversed("ant"))
# Out:
# 't DataScience n DataScience a'

# %%
# type casting
list(reversed("ant"))
# Out:
# ['t', 'n', 'a']

# %%
for i in list(reversed(course_anme)):
  print(i, end='')
# Out:
# sretsaM ecneicS ataD

# %% [markdown]
# # Removing Character from the end of the string

# %%
string_a = " Josmi "

# %%
string_a.strip(" ")
# Out:
# 'Josmi'

# %%
string_a.lstrip()
# Out:
# 'Josmi '

# %%
string_a.rstrip()
# Out:
# ' Josmi'

# %%
string_n = "Greeting to UK"

# %%
string_n.replace("to","from")
# Out:
# 'Greeting from UK'

# %%
string_n.replace("Greeting","Welcome")
# Out:
# 'Welcome to UK'

# %%
string_n = "Greeting to UK"
var_1 = string_n.replace("Greeting","Welcome")

# %%
print(id(string_n))
print(id(var_1))
# Out:
# 132371337243120
# 132371337243888

# %%
'Hello\tworld'.expandtabs()
# Out:
# 'Hello   world'

# %%
str3="Welcome to PW Skills.Welcome to dat cience Masters"

# %%
var_2=str3.replace("dat","data")

# %%
var_2
# Out:
# 'Welcome to PW Skills.Welcome to data cience Masters'

# %%
str3 = var_2.replace("cience","Science")

# %%
str3
# Out:
# 'Welcome to PW Skills.Welcome to data Science Masters'

# %%
str3="Welcome to PW Skills.Welcome to dat cience Masters"

# %%
from os import replace
from os import replace
str3.replace("dat","Data").replace("cience","Science")
# Out:
# 'Welcome to PW Skills.Welcome to Data Science Masters'

# %% [markdown]
# # **How to check whether our string is Uppercase or not**

# %%
str3
# Out:
# 'Welcome to PW Skills.Welcome to dat cience Masters'

# %%
str3.isupper()
# Out:
# False

# %%
str4="HELLO"
str4.isupper()
# Out:
# True

# %%
str5="hello"
str5.islower()
# Out:
# True

# %%
str4.isspace()
# Out:
# False

# %%
str5=" "
str5.isspace()
# Out:
# True

# %%
if " ".isspace():
  print("Hello")
# Out:
# Hello

# %%
str4
# Out:
# 'HELLO'

# %%
print(str4)
str4.endswith("O")
# Out:
# HELLO
# True

# %%
str4.startswith("H")
# Out:
# True

# %% [markdown]
# ## Check if all the character in string are alpha numeric

# %%
a="abc1234"
a.isalnum()
# Out:
# True

# %%
len(str4)
# Out:
# 5

# %%
count=0
for i in str4:
  count=count+1
count
# Out:
# 5

# %%
for i in str4:
  print(i)
# Out:
# H
# E
# L
# L
# O

# %%
range(len(str4))
# Out:
# range(0, 5)

# %%
for i in range(len(str4)):
  print(i,"=",str4[i])
# Out:
# 0 = H
# 1 = E
# 2 = L
# 3 = L
# 4 = O

# %% [markdown]
# # We can use index to iterate string reverse direction using while loop

# %%
b="PWSkills"

# %%
len(b)-1
# Out:
# 7

# %%
for i in range(len(b)-1,-1,-1):
  print(b[i])
# Out:
# s
# l
# l
# i
# k
# S
# W
# P

# %%
for i in range(len(str4)-1,-1,-1):
  print(str4[i])
# Out:
# O
# L
# L
# E
# H

# %%
len(str4)-1
# Out:
# 4

# %%
import string
ch=len(str4)-1
while ch >=0:
  print(str4[ch])
  ch=ch-1
# Out:
# O
# L
# L
# E
# H

# %%
s="pwskills"
td=len(s)-1
while td>=0:
  print(s[td])
  td -=1
# Out:
# s
# l
# l
# i
# k
# s
# w
# p

# %%
for i in range(len(str4)):
  print(str4[len(str4)-(i+1)])
# Out:
# O
# L
# L
# E
# H

# %%
str4[::-1]
# Out:
# 'OLLEH'

# %%
for i in range(len(str4)):
  print(str4[len(str4)-(i+1)], end="")
# Out:
# OLLEH

# %%
Names="pawskills"
vowels="AaEeIiOoUu"

# %%
isvowel=False

for i in Names:
  if (vowels.find(i)>=1):
    print(Names,"Contains vowel of ",i)
    break
  else:
    continue
# Out:
# pawskills Contains vowel of  a

# %%
for ch in Names:
  if ch in vowels:
    print("{} is a vowel".format(ch))
  else:
    print("{} is not a vowel".format(ch))
# Out:
# p is not a vowel
# a is a vowel
# w is not a vowel
# s is not a vowel
# k is not a vowel
# i is a vowel
# l is not a vowel
# l is not a vowel
# s is not a vowel
