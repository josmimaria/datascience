# %% [markdown]
# <a href="https://colab.research.google.com/github/josmimaria/datascience/blob/development/class_method_eng.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class pwskills:
    def __init__(self, name , email):

        self.name = name
        self.email = email

    def student_details(self):
        print(self.name , self.email)

# %%
pw = pwskills("sudh" , "sudh@gmail.com")

# %%
pw.name
# Out:
# 'sudh'

# %%
pw.email
# Out:
# 'sudh@gmail.com'

# %%
pw.student_details()
# Out:
# sudh sudh@gmail.com

# %%
class pwskills1:
    def __init__(self, name , email):

        self.name = name
        self.email = email

    @classmethod
    def details(cls , name1 , email1):
        return cls(name1 , email1)

    def student_details(self):
        print(self.name , self.email)

# %%
pw1 = pwskills1.details("mohan" , "mohan@gamil.com")

# %%
pw1.name
# Out:
# 'mohan'

# %%
pw1.email
# Out:
# 'mohan@gamil.com'

# %%
pw1.student_details()
# Out:
# mohan mohan@gamil.com

# %%
class pwskills2:

    mobile_number = 9134534535

    def __init__(self, name , email):

        self.name = name
        self.email = email

    @classmethod
    def change_number(cls, mobile):
        pwskills2.mobile_number = mobile

    @classmethod
    def details(cls , name1 , email1):
        return cls(name1 , email1)

    def student_details(self):
        print(self.name , self.email,pwskills2.mobile_number)

# %%
pw2_obj = pwskills2("sohil" , "sohil@gmail.com")

# %%
pw2_obj.details("sudh" , "sudh@gmail.com")

# %%
pw2_obj.name
# Out:
# 'sohil'

# %%
pw2_obj.change_number(534553534)

# %%
pw2_obj.mobile_number
# Out:
# 534553534

# %%
pwskills2.mobile_number
# Out:
# 534553534

# %%
pwskills2.change_number(9233345344)

# %%
pwskills2.mobile_number
# Out:
# 9233345344

# %%
pwskills2.mobile_number
# Out:
# 9233345344

# %%
pw2 = pwskills2.details("sohan" , "sohan@gmail.com")

# %%
pw2.student_details()
# Out:
# sohan sohan@gmail.com 9233345344

# %%
pw2_obj = pwskills2("rohan" , "rohan@gmail.com")

# %%
pw2_obj.student_details()
# Out:
# rohan rohan@gmail.com 9233345344

# %%
class pwskills3:

    mobile_number = 9134534535

    def __init__(self, name , email):

        self.name = name
        self.email = email

    @classmethod
    def change_number(cls, mobile):
        pwskills2.mobile_number = mobile

    @classmethod
    def details(cls , name1 , email1):
        return cls(name1 , email1)

    def student_details(self):
        print(self.name , self.email,pwskills2.mobile_number)

# %%
def course_details(cls ,course_name ):
    print("course details" , course_name)

# %%
pwskills3.course_details = classmethod(course_details)

# %%
pwskills3.course_details("data science masters")
# Out:
# course details data science masters

# %%
pw3 = pwskills3("sudh" , "sudh@gmail.com")

# %%
pw3.course_details("web dev")
# Out:
# course details web dev

# %%
class pwskills4:

    mobile_number = 9134534535

    def __init__(self, name , email):

        self.name = name
        self.email = email

    @classmethod
    def change_number(cls, mobile):
        pwskills4.mobile_number = mobile

    @classmethod
    def details(cls , name1 , email1):
        return cls(name1 , email1)

    def student_details(self):
        print(self.name , self.email,pwskills2.mobile_number)

# %%
del pwskills4.change_number

# %%
pwskills4.change_number(2432535345)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_545/395808481.py in <cell line: 0>()
# ----> 1 pwskills4.change_number(2432535345)
#
# AttributeError: type object 'pwskills4' has no attribute 'change_number'

# %%
delattr(pwskills4 , "details")

# %%
pwskills4.mobile_number
# Out:
# 9134534535

# %%
delattr(pwskills4 , "mobile_number")

# %%
pwskills4.mobile_number
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_545/4008415571.py in <cell line: 0>()
# ----> 1 pwskills4.mobile_number
#
# AttributeError: type object 'pwskills4' has no attribute 'mobile_number'

# %%
delattr(pwskills4,"student_details")

# %%
pwskills4
# Out:
# __main__.pwskills4
