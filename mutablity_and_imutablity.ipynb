# %% [markdown]
# <a href="https://colab.research.google.com/github/josmimaria/datascience/blob/development/mutablity_and_imutablity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s = "sudh"

# %%
s[1]
# Out:
# 'u'

# %%
s[-3]
# Out:
# 'u'

# %%
l = [2,3,4,5,6,6,"sudh" , 'josmi' , True, 4+7j]

# %%
type(l)
# Out:
# list

# %%
l[-3]
# Out:
# 'josmi'

# %%
l[7]
# Out:
# 'josmi'

# %%
s
# Out:
# 'sudh'

# %%
l
# Out:
# [2, 3, 4, 5, 6, 6, 'sudh', 'josmi', True, (4+7j)]

# %%
l[6]
# Out:
# 'sudh'

# %%
l[6] = 100

# %%
l
# Out:
# [2, 3, 4, 5, 6, 6, 100, 'josmi', True, (4+7j)]

# %%
s
# Out:
# 'suah'

# %%
s[2] = 'a'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1218/1175681098.py in <cell line: 0>()
# ----> 1 s[2] = 'a'
#
# TypeError: 'str' object does not support item assignment

# %%
s = 'suah'
