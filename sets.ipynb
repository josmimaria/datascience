# %% [markdown]
# <a href="https://colab.research.google.com/github/josmimaria/datascience/blob/development/sets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s = {}

# %%
type(s)
# Out:
# dict

# %%
s1 = {1,2,3,4,5}

# %%
type(s1)
# Out:
# set

# %%
s2 = {1,1,12,3,3,3,4,5,5,5,55,523,34,3,45,6,67}

# %%
s2
# Out:
# {1, 3, 4, 5, 6, 12, 34, 45, 55, 67, 523}

# %%
l = list(s2)

# %%
tuple(s2)
# Out:
# (1, 34, 3, 4, 5, 6, 67, 523, 12, 45, 55)

# %%
l
# Out:
# [1, 34, 3, 4, 5, 6, 67, 523, 12, 45, 55]

# %%
set(l)
# Out:
# {1, 3, 4, 5, 6, 12, 34, 45, 55, 67, 523}

# %%
s4 = {1,2,3,4,[1,2,3,4]}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 s4 = {1,2,3,4,[1,2,3,4]}
#
# TypeError: unhashable type: 'list'

# %%
s5 = {1,2,3,4, (1,2,3,4)}

# %%
s5
# Out:
# {(1, 2, 3, 4), 1, 2, 3, 4}

# %%
s6 = {"sudh" , "Sudh" , 2,3,4,5}

# %%
s6
# Out:
# {2, 3, 4, 5, 'Sudh', 'sudh'}

# %%
s7  = {"sudh" , "sudh" , 2,3,4,5}

# %%
s7
# Out:
# {2, 3, 4, 5, 'sudh'}

# %%
s7
# Out:
# {2, 3, 4, 5, 'sudh'}

# %%
s7[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 s7[0]
#
# TypeError: 'set' object is not subscriptable

# %%
s7[::-1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 s7[::-1]
#
# TypeError: 'set' object is not subscriptable

# %%
s7
# Out:
# {2, 3, 4, 5, 'sudh'}

# %%
for i in s7 :
    print(i)
# Out:
# 2
# 3
# 4
# 5
# sudh

# %%
s7
# Out:
# {2, 3, 4, 5, 'sudh'}

# %%
s7.add(34)

# %%
s7
# Out:
# {2, 3, 34, 4, 5, 'sudh'}

# %%
s7.add(2)

# %%
s7
# Out:
# {2, 3, 34, 4, 5, 'sudh'}

# %%
len(s7)
# Out:
# 6

# %%
s7.pop()
# Out:
# 2

# %%
s7
# Out:
# {3, 34, 4, 5, 'sudh'}

# %%
s7.pop()
# Out:
# 3

# %%
s7.pop()
# Out:
# 4

# %%
s7.pop()
# Out:
# 5

# %%
s7
# Out:
# {34, 'sudh'}

# %%
s7
# Out:
# {34, 'sudh'}

# %%
s7.clear()

# %%
s7
# Out:
# set()

# %%
s8 = {1,2,3,4}
s9 = {1,2,3,5}

# %%
s8.difference(s9)
# Out:
# {4}

# %%
s9.difference(s8)
# Out:
# {5}
